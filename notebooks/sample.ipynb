# %%
from settings import DATACONFIG

config = DATACONFIG["heavy"]
config
# Out:
# heavy [Docs: 100000; Terms: all; Approximation error: 0.35; N Clusters: 175]

# %%
from model.solver import Solver

solver = Solver(config=config)

# %%
solver.solve()
# Out:
# Loading matrix...
# Computing d-gap...
# INFO: Retrieving average d-gaps from disk at /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/avg_d_gap.json.
# INFO: Saving average d-gap per term to /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/avg_d_gap.json.
# Computing embedding...
# Performing clustering...
# INFO: Retrieving labeling from disk at /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/labeling.json.
# INFO: Saving labeling to /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/labeling.json.
# Computing medoids...
# INFO: Retrieving medoids from disk at /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/medoids.npy.
# INFO: Saving medoids to /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/medoids.npy.
# Computing TSP...
# INFO: Medoids already computed. Use `medoids` to retrieve them.
# INFO: Retrieving order from disk at /home/sebaq/Documents/GitHub/IR_project/dataset/heavy/reassignment_order.json.
# ...

# %%
solver.avg_compression
# Out:
# 11.972525447830158
